# %%
import pandas as pd
orig = pd.read_csv("./raw/usa_with_details.csv")

# %%
orig.columns
# Out:
# Index(['a', 'co', 'c', 'd', 'p', 's', 'si', 'ssi', 'stt', 'st', 'LatLong',
#        'Id', 'Zipcode', 'CI', 'SearchError', 'ScamTitle', 'BusinessName', 'C',
#        'D', 'Description', 'P', 'PKID', 'S', 'ScamID'],
#       dtype='object')

# %%
import numpy as np
import re
import textdistance
# we will need scikit-learn>=0.21
from sklearn.cluster import AgglomerativeClustering  

texts = orig["BusinessName"][0:100]

def normalize(text):
  """ Keep only lower-cased text and numbers"""
  return re.sub('[^a-z0-9]+', ' ', text.lower())

def group_texts(texts, threshold=0.3): 
  """ Replace each text with the representative of its cluster"""
  normalized_texts = np.array([normalize(str(text)) for text in texts])
  distances = 1 - np.array([
      [textdistance.jaro_winkler(one, another) for one in normalized_texts] 
      for another in normalized_texts
  ])
  clustering = AgglomerativeClustering(
    distance_threshold=threshold, # this parameter needs to be tuned carefully
    affinity="precomputed", linkage="complete", n_clusters=None
  ).fit(distances)
  centers = dict()
  for cluster_id in set(clustering.labels_):
    index = clustering.labels_ == cluster_id
    centrality = distances[:, index][index].sum(axis=1)
    centers[cluster_id] = normalized_texts[index][centrality.argmin()]
  return [centers[i] for i in clustering.labels_]
groups = group_texts(texts)
for i in range(len(texts)):
    print(f'{i} {groups[i]}')
# Out:
# 0 pay to drive advertising
# 1 better business bereau
# 2 westchester country club
# 3 mvmt marketing inc
# 4 krecklo associates world vision
# 5 zeel
# 6 tencent
# 7 extraymasl
# 8 gse s p a gestore dei servizi energetici
# 9 veloxis pharmaceuticals
# 10 goat group
# 11 ssd market research
# 12 n k i consulting
# 13 esc technology
# 14 dp world
# 15 nexus healthcare
# 16 genstar capital
# 17 pacylex pharma
# 18 career daily
# 19 dave sandifer hatch
# 20 envases group company
# 21 house of schwan inc
# 22 dynamic collective inc
# 23 dunton consulting
# 24 focalpoint llc
# 25 odyssey capital group
# 26 goat group
# 27 ewrix
# 28 nan
# 29 fedex express
# 30 zee forwarding services
# 31 mgm wrap
# 32 envases group company
# 33 goat group
# 34 vixsta solutions llc
# 35 envases group company
# 36 empower recruiter
# 37 ziprecruiter impostor
# 38 laminion home care
# 39 davisware inc chiship services llc
# 40 next level nrg
# 41 syntax post
# 42 rpd packaging
# 43 odyssey capital group
# 44 appdynamics
# 45 focalpoint llc
# 46 abco supply llc imposter
# 47 ziprecruiter impostor
# 48 zuko xpress
# 49 employment
# 50 davisware inc chiship services llc
# 51 merchandise world
# 52 messenger
# 53 annemarie rugel
# 54 nan
# 55 fuel transportation network co
# 56 employment
# 57 nan
# 58 nan
# 59 laminion home care
# 60 first quantum mineral
# 61 ferstey logistic services
# 62 ugl limited
# 63 market force
# 64 atmjobs
# 65 key gainer
# 66 imposter whole foods
# 67 private equity recruiting inc
# 68 texas workforce commision
# 69 conectys
# 70 gfi group of company
# 71 imposter whole foods
# 72 veloxis pharmaceuticals
# 73 nexus healthcare
# 74 personal assistant
# 75 on site shopper
# 76 nemaura medical
# 77 rpd post
# 78 claiming to be with schneider electric
# 79 the temenos ag software company
# 80 laminion home care
# 81 dean company
# 82 star clicks
# 83 gse
# 84 gse s p a gestore dei servizi energetici
# 85 shoe import 44
# 86 perenti global ltd
# 87 inacross research inc
# 88 premium retail
# 89 vixsta solutions llc
# 90 genstar capital
# 91 nan
# 92 esc technology
# 93 rapid label service
# 94 perenti global ltd
# 95 nan
# 96 ismac
# 97 claiming to be with schneider electric
# 98 medical lead consulting llc
# 99 ceva logistics

# %%
orig["BusinessName"][:60]
# Out:
# 0                        Pay To Drive Advertising
# 1                          Better Business Bereau
# 2                       Westchester Country Club
# 3                            MVMT marketing inc.
# 4                Krecklo Associates/ World Vision
# 5                                            Zeel
# 6                                        Tencent
# 7                                      Extraymasl
# 8     GSE S.p.A - Gestore dei Servizi Energetici.
# 9                         Veloxis Pharmaceuticals
# 10                                     GOAT GROUP
# 11                            SSD Market Research
# 12                               N K I Consulting
# 13                                 ESC Technology
# 14                                       DP World
# 15                               Nexus Healthcare
# 16                                Genstar Capital
# 17                                 Pacylex Pharma
# 18                                   Career Daily
# 19                            Dave Sandifer Hatch
# 20                          ENVASES group company
# 21                            House of Schwan Inc
# 22                       Dynamic collective  inc
# 23                              DUNTON CONSULTING
# 24                                FocalPoint LLC
# 25                          Odyssey Capital Group
# 26                                    Lonza Group
# 27                                          Ewrix
# 28                                            NaN
# 29                                  Fedex Express
# 30                       Zee Forwarding Services
# 31                                       MGM WRAP
# 32                                   Envase Group
# 33                                     Mace group
# 34                           Vixsta Solutions LLC
# 35                                Envases Company
# 36                              Empower Recruiter
# 37                         ZipRecruiter- IMPOSTOR
# 38                            LAMINION HOME CARE
# 39          Davisware Inc./ CHISHIP Services LLC/
# 40                                 Next level NRG
# 41                                    Syntax Post
# 42                                  RPD Packaging
# 43                          Odyssey Capital Group
# 44                                    AppDynamics
# 45                           Octagon Payroll Inc.
# 46                       Abco Supply LLC Imposter
# 47                                      I-recruit
# 48                                   Zuko  Xpress
# 49                                    Employment
# 50                         Wish Deliveries US LLC
# 51                              Merchandise World
# 52                                      Messenger
# 53                                Annemarie Rugel
# 54                   RL Enterprise and Associates
# 55                Fuel Transportation Network Co.
# 56                              random employment
# 57                                            NaN
# 58                                            NaN
# 59                             Laminion Home Care
# Name: BusinessName, dtype: object

# %%
import pandas as pd
import numpy as np

# helpful modules
import fuzzywuzzy
from fuzzywuzzy import process
import chardet

# set seed for reproducibility
np.random.seed(0)

# %%
orig_n = orig.shape[0]

# %%
cnt = []
for i in range(orig_n):
    if not isinstance(orig["BusinessName"][i],str):
        orig["BusinessName"][i] = ""
        cnt.append(i)
len(cnt)
# Out:
# 0

# %%
# convert to lower case
orig["BusinessName"] = orig["BusinessName"].str.lower()
# remove trailing white spaces
orig["BusinessName"] = orig["BusinessName"].str.strip()

# %%
cities = orig["BusinessName"].unique()

# sort them alphabetically and then take a closer look
cities.sort()
cities
# Out:
# array(['', '"career advisor"', '"job offer" - mystery shopper', ...,
#        '©2018 sights on service inc', 'æternity crypto foundation',
#        '“lionel”'], dtype=object)

# %%
matches = fuzzywuzzy.process.extract("amazon", cities, limit=200, scorer=fuzzywuzzy.fuzz.partial_ratio)

# %%
matches
# Out:
# [('@amazonprofits.org at amazon profits.org.', 100),
#  ('acting as amazon recruiter', 100),
#  ('acting as amazonprofits.co', 100),
#  ('amazon', 100),
#  ('amazon  job scam', 100),
#  ('amazon - fake', 100),
#  ('amazon affiliate', 100),
#  ('amazon associate website impostor', 100),
#  ('amazon business associates', 100),
#  ('amazon cache website', 100),
#  ('amazon cadh', 100),
#  ('amazon careers', 100),
#  ('amazon cash', 100),
#  ('amazon cash website', 100),
#  ('amazon cash websites', 100),
#  ('amazon cashe website', 100),
#  ('amazon company name spoofing', 100),
#  ('amazon corporate llc imposter', 100),
#  ('amazon data jobs', 100),
#  ('amazon data jobs imposter', 100),
#  ('amazon employment offer imposter', 100),
#  ('amazon employment scam', 100),
#  ('amazon fast inspect goods', 100),
#  ('amazon fast inspect llc', 100),
#  ('amazon fast inspect my pack llc', 100),
#  ('amazon flex', 100),
#  ('amazon flex advertising logo', 100),
#  ('amazon from home', 100),
#  ('amazon from home imposter', 100),
#  ('amazon from home.org', 100),
#  ('amazon gigs', 100),
#  ('amazon help program', 100),
#  ('amazon home career', 100),
#  ('amazon hotline', 100),
#  ('amazon imposter', 100),
#  ('amazon imposter - stock retail', 100),
#  ('amazon imposter - stockretail.org', 100),
#  ('amazon imposter - storejobs', 100),
#  ('amazon impostor', 100),
#  ('amazon inspect logistics', 100),
#  ('amazon inspect my goods', 100),
#  ('amazon inspect my pack llc', 100),
#  ('amazon inspectgoods', 100),
#  ('amazon job imposter', 100),
#  ('amazon jobs', 100),
#  ('amazon jobs imposter', 100),
#  ('amazon money', 100),
#  ('amazon money - amazon imposter', 100),
#  ('amazon money.co', 100),
#  ('amazon money.co name spoofing', 100),
#  ('amazon name spoofing', 100),
#  ('amazon online store', 100),
#  ('amazon pack inspect', 100),
#  ('amazon poser', 100),
#  ('amazon profit', 100),
#  ('amazon profit. co', 100),
#  ('amazon profit.co', 100),
#  ('amazon profits', 100),
#  ('amazon profits - impostor', 100),
#  ('amazon profits co.', 100),
#  ('amazon profits company', 100),
#  ('amazon profits deco', 100),
#  ('amazon profits. org', 100),
#  ('amazon profits.co', 100),
#  ('amazon profits.org', 100),
#  ('amazon profits/ sarah', 100),
#  ('amazon profitsco', 100),
#  ('amazon recruiter', 100),
#  ('amazon recruiter . org', 100),
#  ('amazon referral associated program', 100),
#  ('amazon resources - imposter', 100),
#  ('amazon secret shopper llc', 100),
#  ('amazon spoof', 100),
#  ('amazon wealth', 100),
#  ('amazon wealth. org- impostor', 100),
#  ('amazon wealth.org', 100),
#  ('amazon work from home', 100),
#  ('amazon work from home imposter', 100),
#  ('amazon- spoof', 100),
#  ('amazon-imposter', 100),
#  ('amazoncash.org - amazon imposter', 100),
#  ('amazondata.jobscom', 100),
#  ('amazondatajobs.com', 100),
#  ('amazondatajobs.org', 100),
#  ('amazondatajobs.org - amazon employment scam', 100),
#  ('amazone nonprofit', 100),
#  ('amazonfromhome.org', 100),
#  ('amazongig.org', 100),
#  ('amazongigs.com', 100),
#  ('amazonhiring.org', 100),
#  ('amazoninspectgoods', 100),
#  ('amazonmoney.co', 100),
#  ('amazonmoney.com', 100),
#  ('amazonprofit', 100),
#  ('amazonprofit.co', 100),
#  ('amazonprofit.co - amazon imposter', 100),
#  ('amazonprofit.com spoof', 100),
#  ('amazonprofit.org', 100),
#  ('amazonprofits', 100),
#  ('amazonprofits.co', 100),
#  ('amazonprofits.co a nonprofit recruitment firm', 100),
#  ('amazonprofits.org', 100),
#  ('amazonrecruiter.org', 100),
#  ('amazonresource.org', 100),
#  ('amazonretail.com', 100),
#  ('amazonsellergoods', 100),
#  ('earn with amazon imposter', 100),
#  ('earnusingamazon.com', 100),
#  ('earnwithamazon.com- impostor', 100),
#  ('gold retail.com/ work for amazon', 100),
#  ('imitator of amazon', 100),
#  ('impostor- amazon', 100),
#  ('loan for amazon lfa ltd', 100),
#  ('loan for amazon spoof', 100),
#  ('loanforamazon', 100),
#  ('new amazon seller', 100),
#  ('onlineamazon', 100),
#  ('real profits online - amazon imposter', 100),
#  ('scammer posing as amazon', 100),
#  ('spoofing amazon', 100),
#  ('stockretail.org/amazon', 100),
#  ('stockretail.org/amazon cash website', 100),
#  ('ul group for amazon', 100),
#  ('usa pack inspect or amazon corporate llc', 100),
#  ('webstore jobs for amazon fulfillment', 100),
#  ('webstorejobs for amazon', 100),
#  ('webstorejobs.org claiming to be hiring for amazon', 100),
#  ('webstorejobs.org on behalf of amazon', 100),
#  ('work from home amazon', 100),
#  ('working using amazon dot org', 100),
#  ('amazing gift, llc', 83),
#  ('amazinggiftllc', 83),
#  ('own', 80),
#  ('bill damian', 73),
#  ('dl diamond', 73),
#  ('imposter: harman', 73),
#  ('marian diamond', 73),
#  ('yamana', 73),
#  ('abm', 67),
#  ('absolute financial management inc.', 67),
#  ('agile digital transformation', 67),
#  ('allmond shipers', 67),
#  ('allmond shippers', 67),
#  ('allmond shippers group llc', 67),
#  ('allmond shipping', 67),
#  ('amanda bond', 67),
#  ('amanda cheryl', 67),
#  ('amanda energy imposter', 67),
#  ('amanda energy solutions', 67),
#  ('amanda joy cleaning compan llc??', 67),
#  ('amanpuro  co', 67),
#  ('amarin corporation', 67),
#  ('andaman limited', 67),
#  ('antoniello masonry', 67),
#  ('arizona unemployment', 67),
#  ('ataccama', 67),
#  ('au mann ag', 67),
#  ('avstltd - hampton, va', 67),
#  ('bcg global management consulting', 67),
#  ('black diamond energy inc', 67),
#  ('blackmon mooring', 67),
#  ('brian harris/ avalon healthcare group', 67),
#  ("brigham and women's hospital", 67),
#  ('budweiser auto wrap campaing program', 67),
#  ('camaland logistics', 67),
#  ('carman construction', 67),
#  ('cerissa hinson/delbert raymond', 67),
#  ('champion home builders', 67),
#  ('champion industries inc.', 67),
#  ('chapman consulting', 67),
#  ('cigar city magazine', 67),
#  ('cinnamon shore realty', 67),
#  ('concept stock media - adam longnecker', 67),
#  ('crypto capital management', 67),
#  ('dashman delivey', 67),
#  ('deangelis diamond health care group', 67),
#  ('deangelis diamond healthcare group', 67),
#  ('diamond consulting', 67),
#  ('diamond electric contractor inc', 67),
#  ('diamond eshop llc', 67),
#  ('diamond eshop-us', 67),
#  ('diamond humanity foundation', 67),
#  ("diamond jim's and miss donna's steakhouse", 67),
#  ('diamond links', 67),
#  ('diamond parking', 67),
#  ('diamond resolutions', 67),
#  ('diamond rock partner', 67),
#  ('diamond se', 67),
#  ('diamond touch security', 67),
#  ('diamond vacancy', 67),
#  ('diamondpeak research inc.', 67),
#  ('dickson electrical management', 67),
#  ('digital management llc', 67),
#  ('doma construction', 67),
#  ('elkay manufacturing inc. spoof', 67),
#  ('elysian management group', 67),
#  ('employment - amanda macdonald', 67),
#  ('envira management', 67),
#  ('exmac automation', 67),
#  ('flaunt magazine- impostor', 67)]

# %%
def replace_matches_in_column(df, column, string_to_match, min_ratio = 80):
    # get a list of unique strings
    strings = df[column].unique()
    
    # get the top 10 closest matches to our input string
    matches = fuzzywuzzy.process.extract(string_to_match, strings, 
                                         limit=10, scorer=fuzzywuzzy.fuzz.token_sort_ratio)

    # only get matches with a ratio > 90
    close_matches = [matches[0] for matches in matches if matches[1] >= min_ratio]

    # get the rows of all the close matches in our dataframe
    rows_with_matches = df[column].isin(close_matches)

    # replace all rows with close matches with the input matches 
    df.loc[rows_with_matches, column] = string_to_match
    
    # let us know the function's done
    print("All done!")
